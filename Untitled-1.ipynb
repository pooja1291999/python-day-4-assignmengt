# %%
#islower()
"hellopython".islower()
# Out:
# True

# %%
#isupper()
"HELLOPYTHON".isupper()
# Out:
# True

# %%
"GITHUB REPOSITORY".isupper()
# Out:
# True

# %%
a=input("enter the sentence:")
b=input("enter the word:")
for i in range(len(a)):
    if a.startswith(b,i):
        res=i
        print("the occurrence of the string:"+str(res))
# Out:
# enter the sentence: What we think we become; we are python programmer
# enter the word: we
# the occurrence of the string:5
# the occurrence of the string:14
# the occurrence of the string:25
